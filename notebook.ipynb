# %%
stock = {
    "pains au chocolat": 500,
    "croissants": 400,
    "baguettes": 500,
    "beignets": 200
}

# %%
# Nouveau code propre pour remplacer le précédent
def visualiser_inventaire(inventaire):
    print("--- Rapport d'Inventaire ---")
    for produit, quantite in inventaire.items():
        # Utilisation de capitalize() pour un affichage propre
        print(f"Produit : {produit.capitalize()} | Quantité : {quantite}")

# Test avec votre dictionnaire
visualiser_inventaire(stock)
# Out:
# --- Rapport d'Inventaire ---
# Produit : Pains au chocolat | Quantité : 500
# Produit : Croissants | Quantité : 400
# Produit : Baguettes | Quantité : 500
# Produit : Beignets | Quantité : 200

# %%
def fabriquer(produit, quantite):
    if produit in stock:
        stock[produit] += quantite
        print(f"Succès : {quantite} {produit} ajoutés.")
        print(f"Nouveau total pour {produit} : {stock[produit]}")
    else:
        print(f"Erreur : Le produit '{produit}' n'existe pas dans l'inventaire.")

# --- Tests ---
visualiser_inventaire(stock)
fabriquer("croissants", 50)
# Out:
# --- Rapport d'Inventaire ---
# Produit : Pains au chocolat | Quantité : 500
# Produit : Croissants | Quantité : 400
# Produit : Baguettes | Quantité : 500
# Produit : Beignets | Quantité : 200
# Succès : 50 croissants ajoutés.
# Nouveau total pour croissants : 450
